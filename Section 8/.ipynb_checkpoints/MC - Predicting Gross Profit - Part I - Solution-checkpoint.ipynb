# %% [markdown]
# ## Monte Carlo - Predicting Gross Profit - Part I

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Imagine you are an experienced manager and you have forecasted revenues of \$200mln, with an expected deviation of $10mln. You are convinced Cogs will be near 40% of the revenues, and their expected deviation is 20% of its own value.

# %% [markdown]
# Use NumPy’s random.random function to simulate the potential revenue stream for 250 iterations (which is the number of trading days in a year) and then the predicted Cogs value.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rev_m = 200
rev_stdev = 10
iterations = 250

# %%
rev = np.random.normal(rev_m, rev_stdev, iterations)
rev
# Out:
# array([199.53222823, 196.17258161, 206.64154337, 197.98939533,
#        217.68512331, 200.03172811, 196.42492019, 192.00997384,
#        200.76792821, 202.17685994, 201.54494667, 203.77150161,
#        209.08729116, 190.77595993, 206.74960936, 197.35633119,
#        209.72210059, 188.06941743, 201.05027258, 216.50729242,
#        203.0500572 , 210.27579178, 198.2022834 , 176.36108669,
#        197.39856075, 201.95634946, 195.01941602, 189.54012093,
#        196.29238609, 198.91328766, 184.57574804, 196.43223491,
#        201.94687473, 217.89018829, 195.98602902, 201.25353325,
#        219.00634515, 209.50858046, 204.7706817 , 194.71913002,
#        206.14195886, 194.69474162, 192.13282878, 195.59909619,
#        190.92197244, 190.81071526, 190.41464167, 213.58791133,
#        206.16729608, 206.96079796, 191.67832395, 205.36533034,
#        191.69847374, 203.38737974, 194.94737424, 198.77278763,
#        194.65892348, 189.17321657, 201.39278935, 198.75285273,
#        199.62173889, 209.87829405, 205.68365192, 194.32300979,
#        187.59450165, 203.88925635, 195.76536345, 202.41253854,
#        205.36703387, 200.82717934, 206.74064768, 212.9431389 ,
#        194.04850833, 213.20640106, 203.31701425, 190.5925928 ,
#        205.06203216, 202.56060483, 207.55301707, 200.51496367,
#        199.19701419, 198.1032769 , 209.21153874, 207.957559  ,
#        175.63939892, 192.97877452, 204.30240786, 212.69538058,
#        204.25541395, 215.81210867, 203.37354383, 187.69141579,
#        207.46559798, 211.79586734, 202.63402798, 188.63289738,
#        194.28711174, 207.76006581, 185.39394652, 198.18294566,
#        187.70920338, 204.63774092, 217.19290024, 214.30246332,
#        191.81362886, 193.62980559, 209.52414393, 197.10786897,
#        225.11081112, 198.9036535 , 182.75709591, 201.15455635,
#        211.28429387, 201.60211247, 196.3804524 , 200.78150127,
#        207.58008884, 215.66168382, 185.05349931, 193.42168259,
#        203.53992707, 174.16862128, 207.78612554, 202.56996808,
#        196.4037362 , 186.17229106, 200.06081171, 195.69602045,
#        206.7678475 , 196.62294542, 203.2741189 , 196.88790114,
#        193.9896911 , 218.25278787, 207.98250543, 198.6201808 ,
#        210.67502137, 196.20381446, 200.98887538, 211.61529822,
#        209.68567103, 201.65341596, 197.42681897, 197.2072544 ,
#        204.47098086, 177.34781952, 211.27896879, 191.48446096,
#        183.50854267, 177.64044034, 207.08360863, 201.61096972,
#        214.20990871, 200.92879469, 196.05682777, 201.44468869,
#        220.01284236, 205.33133686, 201.4335289 , 194.85037209,
#        195.233952  , 212.02744626, 198.75362953, 213.51891664,
#        195.20272013, 204.21013354, 185.7098111 , 204.96108643,
#        192.5155424 , 213.52155643, 192.22798171, 183.21839711,
#        190.86876865, 191.0604038 , 207.90017192, 196.96087842,
#        192.99692532, 201.88224833, 198.49163631, 211.24503143,
#        209.46679364, 206.71358796, 187.59081858, 200.51015615,
#        200.26465657, 201.00972893, 203.50254679, 195.36523766,
#        196.44448933, 196.38662775, 187.45913333, 203.79114983,
#        195.78551962, 194.79716487, 195.3115023 , 193.85004352,
#        214.37679646, 193.06345566, 220.34148767, 202.71019074,
#        180.22581299, 201.80415493, 189.77922993, 210.41803624,
#        177.05259255, 203.57139084, 201.704558  , 196.64889666,
#        212.47502742, 199.87010052, 217.2921815 , 199.50281434,
#        187.68862816, 200.91901555, 214.66745354, 211.36470795,
#        196.99916367, 215.08457807, 198.81332426, 208.88358171,
#        206.21658186, 200.93809969, 215.36907152, 205.0211718 ,
#        200.33537076, 197.07558319, 179.45777058, 183.93812671,
#        204.38970671, 204.74964714, 188.43991436, 207.02312419,
#        193.14974662, 227.12644517, 191.49310332, 182.41643483,
#        192.38226262, 188.57327943, 184.72007476, 219.43714595,
#        200.63861787, 198.75175895, 204.39622773, 209.58236218,
#        172.58919933, 197.05563363, 206.70166663, 203.44165185,
#        194.34206088, 183.6072212 ])

# %% [markdown]
# Plot the obtained data for revenues and Cogs on a graph and observe the behavior of the obtained values.

# %%
plt.figure(figsize=(15, 6))
plt.plot(rev)
plt.show()

# %%
COGS = - (rev * np.random.normal(0.4,0.2))
 
plt.figure(figsize=(15, 6))
plt.plot(COGS)
plt.show()

# %% [markdown]
# Cogs mean:

# %%
COGS.mean()
# Out:
# -49.86529186038072

# %% [markdown]
# Cogs std:

# %%
COGS.std()
# Out:
# 2.4205212823570963
