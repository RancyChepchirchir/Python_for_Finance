# %% [markdown]
# ## Monte Carlo - Predicting Gross Profit - Part I

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Imagine you are an experienced manager and you have forecasted revenues of \$200mln, with an expected deviation of $10mln. You are convinced Cogs will be near 40% of the revenues, and their expected deviation is 20% of its own value.

# %% [markdown]
# Use NumPy’s random.random function to simulate the potential revenue stream for 250 iterations (which is the number of trading days in a year) and then the predicted Cogs value.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rev = 200
stdev = 10
iterations = 250
cogs = 0.4 * rev
cogs_stdev = 0.2 * cogs

# %%
rev = np.random.normal(rev, stdev, iterations)
rev
# Out:
# array([194.82183448, 196.28765882, 216.14823402, 215.95613716,
#        210.072022  , 201.39065536, 213.57361344, 206.43267265,
#        193.05747508, 203.56076249, 205.86258838, 204.82340383,
#        214.31978859, 198.02921875, 194.83550296, 201.8327221 ,
#        196.03826427, 214.62500624, 199.91959798, 211.9167642 ,
#        196.36977063, 174.14227732, 204.71234809, 192.10514192,
#        214.66991468, 195.8969781 , 202.57952882, 216.35613946,
#        199.55388973, 196.38941319, 205.60928558, 206.96692948,
#        203.32349856, 187.57879891, 201.48663922, 199.1742291 ,
#        196.14576874, 199.64759531, 219.19723393, 194.61040495,
#        199.3493959 , 194.90112808, 190.00343449, 201.07968683,
#        203.88558827, 189.84999582, 202.39784305, 201.34432129,
#        209.13493449, 184.00966269, 177.72319316, 203.12128871,
#        204.66046474, 196.76372609, 188.79051291, 189.89162625,
#        201.26194207, 195.81837497, 206.49271895, 181.30508114,
#        210.38290937, 199.0947219 , 201.58280684, 209.05729873,
#        220.79757436, 205.8270521 , 215.38244897, 206.80776822,
#        195.70054301, 212.10654618, 183.1880767 , 195.47709934,
#        182.31830693, 209.15648165, 214.40664941, 207.88489216,
#        197.9969768 , 199.23903312, 187.59305346, 193.05668238,
#        193.88891899, 184.65034923, 186.52301299, 197.11533583,
#        192.31656982, 194.57686491, 202.23356534, 183.15734702,
#        200.19162185, 191.08927587, 201.43831052, 195.09015974,
#        201.39505376, 194.30794966, 207.1470172 , 186.15339567,
#        189.62659025, 184.14886666, 210.71664828, 195.88024642,
#        201.89959468, 212.32097362, 205.15074939, 215.99657976,
#        179.28929752, 183.37027396, 198.98547084, 195.48513902,
#        215.06087947, 197.06129521, 206.4047592 , 189.47527007,
#        199.25770554, 176.09894944, 205.16144803, 193.01575921,
#        208.11438648, 197.57178853, 175.48030092, 203.65973825,
#        220.08009017, 199.57570562, 195.73091033, 195.38807227,
#        192.17149669, 212.12311857, 202.59549017, 203.4667456 ,
#        190.39098224, 211.48663938, 198.24105939, 199.55560274,
#        191.30955235, 209.3438012 , 194.01513674, 201.34437751,
#        183.29834278, 212.56183015, 209.35427917, 208.03048215,
#        219.8422506 , 210.47920492, 188.72673253, 197.65297842,
#        194.17210284, 209.53305405, 205.46430007, 205.55519037,
#        205.66928687, 194.78474543, 181.24077688, 205.79376867,
#        200.88340398, 213.60473805, 204.06278065, 207.73019812,
#        189.32965492, 198.43634688, 215.33948356, 199.87448316,
#        215.53681963, 213.96090677, 186.83092074, 204.33372868,
#        213.33897257, 202.0163014 , 192.99163014, 177.95785584,
#        219.6811274 , 188.12906476, 204.89072189, 205.95257287,
#        188.85911279, 198.32119977, 193.56634375, 194.33088833,
#        207.01663069, 199.42473406, 209.65007498, 197.81127712,
#        202.97776356, 211.38234893, 205.18624341, 198.94393936,
#        192.32010919, 186.76652196, 194.67202854, 192.40891527,
#        197.4175732 , 203.40408925, 202.629716  , 207.21733801,
#        191.54271401, 216.5882677 , 204.35631038, 216.16597625,
#        204.56510909, 209.26400435, 195.52333344, 204.45699914,
#        210.10042809, 191.75220166, 207.89401465, 213.94291468,
#        193.82601972, 188.8124306 , 196.33790565, 195.28635274,
#        183.19167472, 209.00910236, 193.41679726, 194.61800304,
#        199.43844961, 200.62063669, 189.71455787, 184.21005243,
#        205.20807155, 183.0614125 , 181.48002965, 201.92956923,
#        182.35055845, 202.47407653, 196.02571425, 191.90553404,
#        188.53080642, 204.86269765, 195.67105423, 198.18984437,
#        201.84715448, 206.40961914, 182.98544601, 205.45764815,
#        175.18854325, 208.69104951, 200.85494438, 191.11665291,
#        190.08510973, 198.62745416, 203.82254673, 198.24647102,
#        214.17269281, 209.05200556, 204.12442895, 202.04323952,
#        197.31946356, 195.49595368, 194.87722582, 209.22363678,
#        192.51436559, 205.00639141])

# %% [markdown]
# Plot the obtained data for revenues and Cogs on a graph and observe the behavior of the obtained values.

# %%
plt.figure(figsize = (10, 6))
plt.plot(rev)
plt.show()

# %%
COGS = - (rev * np.random.normal(0.4,0.2))

plt.figure(figsize = (10, 6))
plt.plot(COGS)
plt.show()

# %% [markdown]
# Cogs mean:

# %%
COGS.mean()
# Out:
# -126.72354739014871

# %% [markdown]
# Cogs std:

# %%
COGS.std()
# Out:
# 6.192480801161059
